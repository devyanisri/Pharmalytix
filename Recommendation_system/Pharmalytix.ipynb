# %% [markdown]
# # Pharmalytix

# %%
# Used to display all the matplotlib graphs inside the notebook
# %matplotlib inline 

# Hiding the warnings
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import opendatasets as od
import re
import seaborn as sns
import matplotlib.pyplot as plt
import tweepy
from wordcloud import WordCloud, STOPWORDS

# %%
sns.set() # Setting the default seaborn style for all the plots

# %% [markdown]
# ## Data Integration

# %%
od.download('https://www.kaggle.com/datasets/thedevastator/drug-performance-evaluation', force=True)
# Out:
# Downloading drug-performance-evaluation.zip to .\drug-performance-evaluation
# 100%|█████████████████████████████████████████████████████████████████████████████| 72.4k/72.4k [00:00<00:00, 4.73MB/s]

# %%
data1 = pd.read_csv('drug-performance-evaluation/Drug.csv')
data1.head()
# Out:
#                    Condition          Drug Indication Type      Reviews  \
# 0  Acute Bacterial Sinusitis  Levofloxacin   On Label   RX  994 Reviews
# 1  Acute Bacterial Sinusitis  Levofloxacin   On Label   RX  994 Reviews
# 2  Acute Bacterial Sinusitis  Moxifloxacin   On Label   RX  755 Reviews
# 3  Acute Bacterial Sinusitis  Azithromycin   On Label   RX  584 Reviews
# 4  Acute Bacterial Sinusitis  Azithromycin   On Label   RX  584 Reviews
#
#    Effective  EaseOfUse  Satisfaction  \
# 0       2.52       3.01          1.84
# 1       2.52       3.01          1.84
# 2       2.78       3.00          2.08
# 3       3.21       4.01          2.57
# 4       3.21       4.01          2.57
#
#                                          Information
# 0  \r\n\t\t\t\t\tLevofloxacin is used to treat a ...
# 1  \r\n\t\t\t\t\tLevofloxacin is used to treat a ...
# 2  \r\n\t\t\t\t\t This is a generic drug. The ave...
# 3  \r\n\t\t\t\t\tAzithromycin is an antibiotic (m...
# 4  \r\n\t\t\t\t\tAzithromycin is an antibiotic (m...

# %%
# Checking for duplicates and removing the duplicates

print('The shape before removing the duplicates from the data set is :',data1.shape)
data1 = data1.drop_duplicates()
print('The shape after removing the duplicates from the data set is :',data1.shape)
# Out:
# The shape before removing the duplicates from the data set is : (2219, 9)
# The shape after removing the duplicates from the data set is : (1753, 9)

# %%
data2 = pd.read_csv('drug-performance-evaluation/Drug_clean.csv')
data2.head()
# Out:
#                    Condition                         Drug  EaseOfUse  \
# 0  Acute Bacterial Sinusitis                  Amoxicillin   3.852353
# 1  Acute Bacterial Sinusitis  Amoxicillin-Pot Clavulanate   3.470000
# 2  Acute Bacterial Sinusitis  Amoxicillin-Pot Clavulanate   3.121429
# 3  Acute Bacterial Sinusitis                   Ampicillin   2.000000
# 4  Acute Bacterial Sinusitis                   Ampicillin   3.250000
#
#    Effective            Form Indication       Price     Reviews  Satisfaction  \
# 0   3.655882         Capsule   On Label   12.590000   86.294118      3.197647
# 1   3.290000  Liquid (Drink)  Off Label  287.370000   43.000000      2.590000
# 2   2.962857          Tablet   On Label   70.608571  267.285714      2.248571
# 3   3.000000         Capsule   On Label   12.590000    1.000000      1.000000
# 4   3.000000          Tablet   On Label  125.240000   15.000000      3.000000
#
#   Type
# 0   RX
# 1   RX
# 2   RX
# 3   RX
# 4   RX

# %%
# Checking for duplicates and removing the duplicates

print('The shape before removing the duplicates from the data set is :',data2.shape)
data2 = data2.drop_duplicates()
print('The shape after removing the duplicates from the data set is :',data2.shape)
# Out:
# The shape before removing the duplicates from the data set is : (685, 10)
# The shape after removing the duplicates from the data set is : (685, 10)

# %%
data = data1.merge(data2.drop(['EaseOfUse', 'Effective', 'Indication','Reviews', 'Satisfaction', 'Type'], axis=1), 
                on = ['Condition', 'Drug'], how ='left')

data.head(10)
# Out:
#                    Condition                         Drug Indication Type  \
# 0  Acute Bacterial Sinusitis                 Levofloxacin   On Label   RX
# 1  Acute Bacterial Sinusitis                 Moxifloxacin   On Label   RX
# 2  Acute Bacterial Sinusitis                 Azithromycin   On Label   RX
# 3  Acute Bacterial Sinusitis  Amoxicillin-Pot Clavulanate   On Label   RX
# 4  Acute Bacterial Sinusitis  Amoxicillin-Pot Clavulanate   On Label   RX
# 5  Acute Bacterial Sinusitis                 Levofloxacin   On Label   RX
# 6  Acute Bacterial Sinusitis                  Amoxicillin   On Label   RX
# 7  Acute Bacterial Sinusitis               Clarithromycin   On Label   RX
# 8  Acute Bacterial Sinusitis  Amoxicillin-Pot Clavulanate   On Label   RX
# 9  Acute Bacterial Sinusitis  Amoxicillin-Pot Clavulanate   On Label   RX
#
#        Reviews  Effective  EaseOfUse  Satisfaction  \
# 0  994 Reviews       2.52       3.01          1.84
# 1  755 Reviews       2.78       3.00          2.08
# 2  584 Reviews       3.21       4.01          2.57
# 3  437 Reviews       3.26       3.23          2.42
# 4  437 Reviews       3.26       3.23          2.42
# 5  361 Reviews       2.44       2.96          1.68
# 6  353 Reviews       3.04       3.37          2.34
# 7  222 Reviews       3.00       3.40          2.18
# 8  140 Reviews       2.74       3.04          2.12
# 9  140 Reviews       2.74       3.04          2.12
#
#                                          Information            Form  \
# 0  \r\n\t\t\t\t\tLevofloxacin is used to treat a ...          Tablet
# 1  \r\n\t\t\t\t\t This is a generic drug. The ave...  Liquid (Drink)
# 2  \r\n\t\t\t\t\tAzithromycin is an antibiotic (m...          Tablet
# 3  \r\n\t\t\t\t\tAmoxicillin/clavulanic acid is a...  Liquid (Drink)
# 4  \r\n\t\t\t\t\tAmoxicillin/clavulanic acid is a...          Tablet
# 5  \r\n\t\t\t\t\tLevofloxacin is used to treat a ...          Tablet
# 6  \r\n\t\t\t\t\tAmoxicillin is used to treat a w...         Capsule
# 7  \r\n\t\t\t\t\tClarithromycin is used to treat ...          Tablet
# 8  \r\n\t\t\t\t\tAmoxicillin/clavulanic acid is a...  Liquid (Drink)
# 9  \r\n\t\t\t\t\tAmoxicillin/clavulanic acid is a...          Tablet
#
#         Price
# 0  172.990000
# 1   74.990000
# 2   32.100000
# 3  287.370000
# 4   70.608571
# 5  172.990000
# 6   12.590000
# 7   99.490000
# 8  287.370000
# 9   70.608571

# %%
# Checking for duplicates and removing the duplicates

print('The shape before removing the duplicates from the data set is :',data.shape)
data = data.drop_duplicates()
print('The shape after removing the duplicates from the data set is :',data.shape)
# Out:
# The shape before removing the duplicates from the data set is : (2624, 11)
# The shape after removing the duplicates from the data set is : (2377, 11)

# %%
data.head(10)
# Out:
#                    Condition                         Drug Indication Type  \
# 0  Acute Bacterial Sinusitis                 Levofloxacin   On Label   RX
# 1  Acute Bacterial Sinusitis                 Moxifloxacin   On Label   RX
# 2  Acute Bacterial Sinusitis                 Azithromycin   On Label   RX
# 3  Acute Bacterial Sinusitis  Amoxicillin-Pot Clavulanate   On Label   RX
# 4  Acute Bacterial Sinusitis  Amoxicillin-Pot Clavulanate   On Label   RX
# 5  Acute Bacterial Sinusitis                 Levofloxacin   On Label   RX
# 6  Acute Bacterial Sinusitis                  Amoxicillin   On Label   RX
# 7  Acute Bacterial Sinusitis               Clarithromycin   On Label   RX
# 8  Acute Bacterial Sinusitis  Amoxicillin-Pot Clavulanate   On Label   RX
# 9  Acute Bacterial Sinusitis  Amoxicillin-Pot Clavulanate   On Label   RX
#
#        Reviews  Effective  EaseOfUse  Satisfaction  \
# 0  994 Reviews       2.52       3.01          1.84
# 1  755 Reviews       2.78       3.00          2.08
# 2  584 Reviews       3.21       4.01          2.57
# 3  437 Reviews       3.26       3.23          2.42
# 4  437 Reviews       3.26       3.23          2.42
# 5  361 Reviews       2.44       2.96          1.68
# 6  353 Reviews       3.04       3.37          2.34
# 7  222 Reviews       3.00       3.40          2.18
# 8  140 Reviews       2.74       3.04          2.12
# 9  140 Reviews       2.74       3.04          2.12
#
#                                          Information            Form  \
# 0  \r\n\t\t\t\t\tLevofloxacin is used to treat a ...          Tablet
# 1  \r\n\t\t\t\t\t This is a generic drug. The ave...  Liquid (Drink)
# 2  \r\n\t\t\t\t\tAzithromycin is an antibiotic (m...          Tablet
# 3  \r\n\t\t\t\t\tAmoxicillin/clavulanic acid is a...  Liquid (Drink)
# 4  \r\n\t\t\t\t\tAmoxicillin/clavulanic acid is a...          Tablet
# 5  \r\n\t\t\t\t\tLevofloxacin is used to treat a ...          Tablet
# 6  \r\n\t\t\t\t\tAmoxicillin is used to treat a w...         Capsule
# 7  \r\n\t\t\t\t\tClarithromycin is used to treat ...          Tablet
# 8  \r\n\t\t\t\t\tAmoxicillin/clavulanic acid is a...  Liquid (Drink)
# 9  \r\n\t\t\t\t\tAmoxicillin/clavulanic acid is a...          Tablet
#
#         Price
# 0  172.990000
# 1   74.990000
# 2   32.100000
# 3  287.370000
# 4   70.608571
# 5  172.990000
# 6   12.590000
# 7   99.490000
# 8  287.370000
# 9   70.608571

# %% [markdown]
# ## Exploratory Data Analysis

# %%
data.info() # Checking for the data type of each of the variables and the number of non-null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2377 entries, 0 to 2623
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Condition     2377 non-null   object
#  1   Drug          2377 non-null   object
#  2   Indication    2377 non-null   object
#  3   Type          2377 non-null   object
#  4   Reviews       2377 non-null   object
#  5   Effective     2377 non-null   float64
#  6   EaseOfUse     2377 non-null   float64
#  7   Satisfaction  2377 non-null   float64
#  8   Information   2377 non-null   object
#  9   Form          2377 non-null   object
#  10  Price         2377 non-null   float64
# dtypes: float64(4), object(7)
# memory usage: 222.8+ KB

# %%
data.nunique() # Getting a count of number of unique values in each column so as to identify the continuous and discrete variables
# Out:
# Condition        37
# Drug            470
# Indication        3
# Type              4
# Reviews         241
# Effective       207
# EaseOfUse       184
# Satisfaction    223
# Information     421
# Form              6
# Price           332
# dtype: int64

# %%
#Checking for Missing Values
data.isna().sum()
# Out:
# Condition       0
# Drug            0
# Indication      0
# Type            0
# Reviews         0
# Effective       0
# EaseOfUse       0
# Satisfaction    0
# Information     0
# Form            0
# Price           0
# dtype: int64

# %%
# Five-point summary

data.describe().T
# Out:
#                count        mean         std  min    25%    50%    75%  \
# Effective     2377.0    3.538494    1.123914  1.0   3.00   3.70   4.33
# EaseOfUse     2377.0    3.956382    1.040115  1.0   3.50   4.09   5.00
# Satisfaction  2377.0    3.200719    1.229683  1.0   2.41   3.13   4.00
# Price         2377.0  117.804227  475.904897  4.0  12.11  23.99  88.99
#
#                    max
# Effective         5.00
# EaseOfUse         5.00
# Satisfaction      5.00
# Price         10362.19

# %% [markdown]
# ## Uni-Variate Analysis

# %%
# Distributions of continuous variables

c_cols = ['Effective', 'EaseOfUse', 'Satisfaction', 'Price']
for column in c_cols :
    plt.close()
    sns.distplot(data[column])
    plt.show()

# %%
# Distributions of discrete variables

d_cols = ['Indication', 'Type', 'Form']
for column in d_cols :
    plt.close()
    sns.countplot(data[column])
    plt.show()

# %% [markdown]
# ## Bi-Variate Analysis

# %%
sns.pairplot(data)

# %%
corr = data.corr() # Finding the correlation between the variables
corr
# Out:
#               Effective  EaseOfUse  Satisfaction     Price
# Effective      1.000000   0.604446      0.816542  0.009715
# EaseOfUse      0.604446   1.000000      0.601047 -0.053196
# Satisfaction   0.816542   0.601047      1.000000  0.000164
# Price          0.009715  -0.053196      0.000164  1.000000

# %%
fig, ax = plt.subplots(figsize=(13,13))
sns.heatmap(corr, annot=True,ax=ax,cmap='GnBu')
# Out:
# <Axes: >

# %% [markdown]
# ### Question 1: What are Top 10 Expensive Drugs Ordered by Price

# %%
q1 = data[['Drug','Condition','Price']]
q1.drop_duplicates(inplace = True)
q1.sort_values(['Price'],ascending=False).head(10).reset_index(drop=True)
# Out:
#                              Drug                                 Condition  \
# 0        Paclitaxel-Protein Bound                adenocarcinoma of pancreas
# 1                     Tigecycline  diverticulitis of gastrointestinal tract
# 2  Hydrocortisone-Iodoquinl-Aloe2                         Atopic Dermatitis
# 3                    Capecitabine                adenocarcinoma of pancreas
# 4                       Nafarelin                             endometriosis
# 5             Triptorelin Pamoate                             endometriosis
# 6                    Fluocinonide                         Atopic Dermatitis
# 7                     Oxaliplatin                adenocarcinoma of pancreas
# 8                       Mitomycin                adenocarcinoma of pancreas
# 9                      Alirocumab                      hypercholesterolemia
#
#           Price
# 0  10362.190000
# 1   7991.990000
# 2   7323.990000
# 3   5829.190000
# 4   3339.990000
# 5   2927.990000
# 6   2564.323333
# 7   2049.590000
# 8   1516.090000
# 9   1387.990000

# %% [markdown]
# ### Question 2: Which form people most prefer (counting the form)

# %%
sns.countplot(data=data,x='Form',order = data['Form'].value_counts().index)
plt.title('Most prefered form of medicine')
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3, 4, 5]),
#  [Text(0, 0, 'Tablet'),
#   Text(1, 0, 'Liquid (Drink)'),
#   Text(2, 0, 'Cream'),
#   Text(3, 0, 'Capsule'),
#   Text(4, 0, 'Liquid (Inject)'),
#   Text(5, 0, 'Other')])

# %% [markdown]
# ### Question 3: Which are the 5 most important health conditions?

# %%
sns.countplot(data=data,x='Condition',order = data['Condition'].value_counts().iloc[:5].index)
plt.title('Ten Most Common Health Conditions')
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3, 4]),
#  [Text(0, 0, 'fever'),
#   Text(1, 0, 'hypertension'),
#   Text(2, 0, 'Atopic Dermatitis'),
#   Text(3, 0, 'endometriosis'),
#   Text(4, 0, 'gout')])

# %% [markdown]
# ### Question 4: What % of people get medicines with prescription?

# %%
data['Type'].value_counts()
# Out:
# RX        1413
# OTC        879
# RX/OTC      70
# \r\n        15
# Name: Type, dtype: int64

# %%
sns.countplot(data=data,x='Type',order = data['Type'].value_counts().index)
plt.title('Most Preferred Type of Medicines')
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3]),
#  [Text(0, 0, 'RX'),
#   Text(1, 0, 'OTC'),
#   Text(2, 0, 'RX/OTC'),
#   Text(3, 0, '\r\n')])

# %% [markdown]
# ### Question 5: Top 5 Health Conditions for Different means of getting Medicines

# %%
# RX
d1 = data[['Condition','Type']][data['Type']=='RX']
sns.countplot(
        data=d1, y="Condition",
        order = d1['Condition'].value_counts().iloc[:5].index,
        palette="pastel", edgecolor=".6",
    )
# Out:
# <Axes: xlabel='count', ylabel='Condition'>

# %%
# OTC
d1 = data[['Condition','Type']][data['Type']=='OTC']
sns.countplot(
        data=d1, y="Condition",
        order = d1['Condition'].value_counts().iloc[:5].index,
        palette="pastel", edgecolor=".6",
    )
# Out:
# <Axes: xlabel='count', ylabel='Condition'>

# %% [markdown]
# ### Question 6: Ease of use vs satisfaction vs Indication

# %%
sns.relplot(data=data[(data['Indication']=='On Label')|(data['Indication']=='Off Label')],
            x='EaseOfUse',
            y='Satisfaction',
            hue='Indication',
            palette='Set2')

# %%
sns.relplot(data=data,
            x='EaseOfUse',
            y='Satisfaction',
            hue='Form',
           palette='Set2')

# %% [markdown]
# # -------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Wordcloud

# %% [markdown]
# ### Pre-Processing the Text Data

# %%
information = data['Information'].values
 
# Converting the text column as a single string for wordcloud
information_string = str(information)
 
# Converting the whole text to lowercase
information_string_cleaned = information_string.lower()
 
# Removing the twitter usernames from information string
information_string_cleaned = re.sub(r'@\w+', ' ', information_string_cleaned)
 
# Removing the URLS from the information string
information_string_cleaned = re.sub(r'http\S+', ' ', information_string_cleaned)
 
# Deleting everything which is not characters
information_string_cleaned = re.sub(r'[^a-z A-Z]', ' ',information_string_cleaned)
 
# Deleting any word which is less than 3-characters mostly those are stopwords
information_string_cleaned = re.sub(r'\b\w{1,2}\b', '', information_string_cleaned)
 
# Stripping extra spaces in the text
information_string_cleaned = re.sub(r' +', ' ', information_string_cleaned)
 
information_string_cleaned
# Out:
# ' tlevofloxacin used treat variety bacterial infections this generic drug the average cash price for tablet each the generic levofloxacin you can buy levofloxacin the discounted price using the webmdrx coupon savings even this drug covered medicare your insurance recommend you compare prices the webmdrx coupon cash price may less than your pay this generic drug the average cash price for bottle each the generic moxifloxacin hcl you can buy moxifloxacin hcl the discounted price using the webmdrx coupon savings even this drug covered medicare your insurance recommend you compare prices the webmdrx coupon cash price may less than your pay tazithromycin antibiotic macrolide type this generic drug the average cash price for disp pack tablets each the generic azithromycin you can buy azithromycin the discounted price using the webmdrx coupon savings even this drug covered medicare your insurance recommend you compare prices the webmdrx coupon cash price may less than your pay tthis medication used treat vaginal yeast infections this brand name drug and generic may available the average cash price for box each you can buy gynazole the discounted price using the webmdrx coupon savings even this drug covered medicare your insurance recommend you compare prices the webmdrx coupon cash price may less than your pay tthis medication used treat vaginal yeast infections this brand name drug and generic may available you can buy monistat the discounted price using the webmdrx coupon even this drug covered medicare your insurance recommend you compare prices the webmdrx coupon cash price may less than your pay tthis medication used treat vaginal yeast infections this brand name drug and generic may available you can buy monistat the discounted price using the webmdrx coupon even this drug covered medicare your insurance recommend you compare prices the webmdrx coupon cash price may less than your pay '

# %%
wordcloudimage = WordCloud(
                          max_words=100,
                          max_font_size=500,
                          font_step=2,
                          stopwords=STOPWORDS,
                          background_color='white',
                          width=1000,
                          height=720
                          ).generate(information_string_cleaned)
 
plt.figure(figsize=(15,7))
plt.axis("off")
plt.imshow(wordcloudimage)
wordcloudimage
plt.show()

# %% [markdown]
# # -------------------------------------------------------------------------------------------------------
